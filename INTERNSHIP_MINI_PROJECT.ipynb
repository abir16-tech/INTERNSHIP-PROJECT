# %% [markdown]
# <a href="https://colab.research.google.com/github/abir16-tech/INTERNSHIP-PROJECT/blob/main/INTERNSHIP_MINI_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Cell 1: Imports and Setup
import pandas as pd
import random
import time

# Display configuration for better output presentation
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

print("Setup complete. Pandas, Random, and Time libraries are ready.")
# Out:
# Setup complete. Pandas, Random, and Time libraries are ready.

# %%
# Cell 2: Web Scraping Module (Simulation)
# These functions simulate data extraction from two different e-commerce sites.
# In a real project, this is where you would use BeautifulSoup or Scrapy.

def scrape_site_A():
    """Simulates scraping the product data from E-commerce Site A."""
    print("  -> Scraping data from ElectroMart.com...")
    # Simulate slight price variation (dynamic data)
    price = round(random.uniform(125.00, 135.00), 2)
    time.sleep(0.1)
    return {
        'product': 'Noise Cancelling Headphones (Model X)',
        'price': price,
        'rating': 4.5,
        'seller': 'ElectroMart.com',
        'timestamp': pd.Timestamp.now()
    }

def scrape_site_B():
    """Simulates scraping the product data from E-commerce Site B."""
    print("  -> Scraping data from TechDeals.co...")
    price = round(random.uniform(130.00, 140.00), 2)
    time.sleep(0.1)
    return {
        'product': 'Noise Cancelling Headphones (Model X)',
        'price': price,
        'rating': 4.7,
        'seller': 'TechDeals.co',
        'timestamp': pd.Timestamp.now()
    }

print("Scraping functions defined and ready to execute.")
# Out:
# Scraping functions defined and ready to execute.

# %%
# Cell 3: Data Processing, Storage, and Analysis Workflow

def run_price_scout():
    """Runs the full scraping, processing, and analysis workflow."""
    print("\n--- 🏁 Starting Price Scout Workflow ---")

    # Step 1: Collect raw data from simulated scrapers
    print("1. Collecting raw data...")
    raw_data = [scrape_site_A(), scrape_site_B()]

    # Step 2: Convert to a Pandas DataFrame (Data Cleaning & Normalization)
    # This step handles data standardization and structure.
    print("\n2. Cleaning and structuring data with Pandas...")
    df = pd.DataFrame(raw_data)

    # Step 3: Save to CSV (Data Storage Module)
    file_name = 'price_comparison_data.csv'
    df.to_csv(file_name, index=False)
    print(f"\n✅ Data successfully saved to '{file_name}' (Data Storage Layer).")

    # Step 4: Data Analysis Module
    print("\n3. Running Competitive Price Analysis...")

    # Find the row with the minimum price (The core actionable intelligence)
    best_price_row = df.loc[df['price'].idxmin()]

    best_price = best_price_row['price']
    best_seller = best_price_row['seller']

    # Print the actionable insight
    print("\n-------------------------------------------------")
    print("🚀 Competitive Pricing Insight (Actionable Intelligence)")
    print(f"Product: {best_price_row['product']}")
    print(f"The current lowest price found is **${best_price:.2f}** from **{best_seller}**.")
    print("-------------------------------------------------")

    return df

# The function is defined, but not yet run.
print("Workflow function 'run_price_scout' defined.")
# Out:
# Workflow function 'run_price_scout' defined.

# %%
# Cell 4: Execute the Workflow
# This runs the full simulation and stores the results in the 'final_df' variable.
final_df = run_price_scout()
# Out:
# --- 🏁 Starting Price Scout Workflow ---
# 1. Collecting raw data...
#   -> Scraping data from ElectroMart.com...
#   -> Scraping data from TechDeals.co...
#
# 2. Cleaning and structuring data with Pandas...
#
# ✅ Data successfully saved to 'price_comparison_data.csv' (Data Storage Layer).
#
# 3. Running Competitive Price Analysis...
#
# -------------------------------------------------
# 🚀 Competitive Pricing Insight (Actionable Intelligence)
# Product: Noise Cancelling Headphones (Model X)
# The current lowest price found is **$126.89** from **ElectroMart.com**.
# -------------------------------------------------

# %%
# Cell 5: Verify Data Storage (Read the saved CSV file back into memory)
print("--- Verifying Data Storage: Reading from saved CSV file ---")

# Load the file back into a new DataFrame to show it was successfully written
df_verification = pd.read_csv('price_comparison_data.csv')

# Display the resulting DataFrame as a formatted table
df_verification
# Out:
# --- Verifying Data Storage: Reading from saved CSV file ---
#                                  product   price  rating           seller                   timestamp
# 0  Noise Cancelling Headphones (Model X)  126.89     4.5  ElectroMart.com  2025-11-30 05:14:23.783880
# 1  Noise Cancelling Headphones (Model X)  134.33     4.7     TechDeals.co  2025-11-30 05:14:23.884144
